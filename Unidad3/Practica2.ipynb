# %% [markdown]
# <a href="https://colab.research.google.com/github/YisusKraizz/Unidad3/blob/main/Unidad3/Practica2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Variables Aleatorias#
#
# ###Practica 2: Simular tiempos de inactividad de un brazo de robot de soldadura en una fábrica de vehículos

# %% [markdown]
# ##Método de la transformada inversa:
#
# Este método genera variables aleatorias de una distribución específica, transformando números aleatorios uniformes (0,1) en variables con la distribución deseada.
#
# ##Distribución exponencial:
#
# La distribución exponencial modela el tiempo entre eventos que ocurren independientemente a una tasa constante. Se define por un parámetro de tasa (
# 𝜆
# ), representando la tasa promedio de eventos por unidad de tiempo. Cuanto mayor sea
# 𝜆
# , más eventos ocurrirán en un período dado.
#
# ##Ejemplo de aplicación:
#
# Supongamos que el tiempo promedio de inactividad de un brazo de robot es de 10 minutos, lo que implica una tasa de inactividad (
# 𝜆
# ) de
# 1
# 10
#  eventos por minuto. El método de la transformada inversa se puede usar para simular estos tiempos de inactividad, asumiendo que siguen una distribución exponencial.
#
# ##Contexto:
#
# La distribución exponencial es adecuada para modelar los tiempos entre eventos con una probabilidad constante a lo largo del tiempo, como fallos o inicios de inactividad en un sistema industrial. Este modelo es útil para la planificación de producción y gestión de recursos en fábricas.
#
# Pasos para generar tiempos de inactividad:
#
# Generar un número aleatorio uniforme
# 𝑈
#  en el intervalo (0,1).
#
# Aplicar la transformada inversa
# 𝑇
# =
# −
# 1
# 𝜆
# ln
# ⁡
# (
# 𝑈
# )
#  para obtener la variable aleatoria con la distribución deseada.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parámetro de la distribución exponencial (tasa de inactividad)
lambda_inactividad = 1 / 10  # Tiempo promedio de inactividad = 10 minutos

# Función para generar un tiempo de inactividad
def generar_tiempo_inactividad(lambda_inactividad):
    u = np.random.uniform(0, 1)  # Generar número aleatorio uniforme
    # Aplicar transformada inversa
    tiempo_inactividad = -1 / lambda_inactividad * np.log(u)
    return tiempo_inactividad

# Generar 100 tiempos de inactividad
tiempos_inactividad = [generar_tiempo_inactividad(lambda_inactividad) for _ in range(100)]

# Mostrar los tiempos de inactividad generados
print("Tiempos de inactividad generados:", tiempos_inactividad)

# Graficar los tiempos de inactividad simulados
plt.hist(tiempos_inactividad, bins=10, edgecolor='black', alpha=0.7)
plt.title('Distribución de Tiempos de Inactividad Simulados (Exponencial)')
plt.xlabel('Tiempo de inactividad (minutos)')
plt.ylabel('Frecuencia')
plt.show()
# Out:
# Tiempos de inactividad generados: [14.376433856112447, 24.227916311956385, 0.08413902285924679, 5.217412276110611, 2.5040994470729148, 1.9586637099595106, 3.818562493402753, 0.20613443753039595, 2.5366203801583835, 0.34575182519538583, 4.680765822585546, 1.7266519369694364, 10.550708167315012, 0.30145573283239047, 3.4166048607215442, 6.757310099310553, 3.072128143532874, 7.669696038954789, 3.034692733870053, 15.548040995173917, 24.971595950853626, 2.7660144637931525, 8.086752425115927, 2.354335107622375, 0.44333894631016973, 17.98574127898332, 6.86757767505608, 5.888828645392531, 2.4090241839947355, 11.704959959430308, 7.786365494933943, 4.307269320772576, 3.0306274159590134, 31.59731970807166, 11.551976348216634, 1.9754466169654816, 19.97360793601818, 0.14557942658594825, 8.321430463087973, 7.007271408334201, 6.076325080745876, 16.772503027371155, 1.1966821061560893, 18.31717374363292, 9.830110385670311, 2.977269273704737, 23.11511803436951, 14.70111809406113, 6.1308628223198225, 0.
# ...

# %% [markdown]
# #Conclusión
#
# Con esta simulación, hemos generado tiempos de inactividad de un brazo de robot de soldadura utilizando el método de la transformada inversa aplicada a una distribución exponencial. Esta técnica nos permite modelar y predecir los tiempos entre eventos de inactividad en un entorno industrial, lo cual es crucial para la planificación de la producción y la gestión eficiente de los recursos en una fábrica de vehículos. Este enfoque puede ayudar a anticipar mantenimientos y fallos, minimizando el tiempo de inactividad y optimizando la operatividad del sistema.
