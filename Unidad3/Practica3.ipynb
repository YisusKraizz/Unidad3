# %% [markdown]
# <a href="https://colab.research.google.com/github/YisusKraizz/Unidad3/blob/main/Unidad3/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Practica 3: Simular los tiempos de servicio o inactividad en una fábrica de chips.

# %% [markdown]
# ##Método de la transformada inversa:
#
# Este método transforma números aleatorios uniformes (0,1) en variables de una distribución específica.
#
# ##Distribución Lognormal:
#
# Se utiliza principalmente para modelar tiempos de servicio o inactividad con asimetría positiva. Los valores son siempre positivos y tienden a distribuirse asimétricamente con una "cola" hacia la derecha, usada cuando los tiempos de servicio tienen gran variabilidad.
#
# ##Ejemplo de Aplicación:
#
# En una fábrica de chips, los tiempos de inactividad de brazos automatizados pueden seguir una distribución lognormal, permitiendo simular estos tiempos y planificar mantenimientos preventivos.
#
# ##Pasos para aplicar el método:
#
# Generar un número aleatorio
# 𝑈
# ∼
# (
# 0
# ,
# 1
# )
# .
#
# Aplicar la transformada inversa usando la inversa de la función de distribución acumulada estándar normal para obtener la variable aleatoria lognormal.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parámetros de la distribución lognormal
mu = 1.0   # Media de la variable logarítmica
sigma = 0.5  # Desviación estándar de la variable logarítmica
n = 100  # Número de variables aleatorias a generar

# Generar n números aleatorios U ~ Uniform(0, 1)
U = np.random.uniform(0, 1, n)

# Transformada inversa para generar tiempos de inactividad lognormales
Z = mu + sigma * stats.norm.ppf(U)
T = np.exp(Z)  # Tiempos generados

# Mostrar los resultados
print("Tiempos de inactividad generados:", T)

# Graficar histograma de los tiempos de inactividad generados
plt.hist(T, bins=20, edgecolor='black', density=True)

# Graficar la función teórica de densidad de la distribución lognormal
x = np.linspace(min(T), max(T), 100)
pdf = stats.lognorm.pdf(x, sigma, scale=np.exp(mu))
plt.plot(x, pdf, 'r', label='Distribución lognormal teórica')

plt.title("Histograma de los tiempos de inactividad (Distribución Lognormal)")
plt.xlabel("Tiempo de inactividad")
plt.ylabel("Densidad de probabilidad")
plt.legend()
plt.show()
# Out:
# Tiempos de inactividad generados: [ 1.97310339  5.8757594   3.04743376  2.81996234  2.88774416  2.05769993
#   2.35522697  2.92864985  2.96026025  6.0534397   2.91074971  2.04585089
#   1.48590497  2.30168527  5.82283493  1.88778201  3.36035483  6.21878191
#   2.31005949  2.46172347  2.92687788  2.78194073  4.11373687  2.26293178
#   4.24029964  2.6900069   2.46575054  1.81201009  2.37911645  4.43290885
#   2.38920129  1.71294739  1.8074797   1.98766533  5.42849269  3.14620207
#   1.35959021  2.99947541  3.12508711  6.43364857  2.04537623  2.08022795
#   0.9488438   1.60503158  1.30508203  4.69163463  3.73844428  3.49734655
#   1.17250588  3.88353022  2.87408877  3.32460013  5.2747009   0.88648224
#   3.01696241  1.16418986  3.93600479  2.11108316  1.39633746  3.61191253
#   1.81765618  5.01736586  1.38074876  3.34082313  6.01156526  3.56413568
#   1.86027475  1.18832207  0.93263913  1.18705246  2.71805271 11.53149762
# ...

# %% [markdown]
# #Conclusión
#
# El código d nos permite simular tiempos de servicio o inactividad en una fábrica de chips usando el método de la transformada inversa y la distribución lognormal. Este enfoque es útil para modelar tiempos de inactividad que son mayoritariamente cortos pero que ocasionalmente pueden ser mucho más largos debido a problemas complejos. Con esta simulación, se puede:
#
# Predecir y analizar la frecuencia y duración de las interrupciones en los brazos automatizados de la línea de producción.
#
# Optimizar la planificación de mantenimientos preventivos y correctivos, minimizando el impacto en la producción.
#
# Mejorar la eficiencia general del sistema, anticipando tiempos de inactividad y ajustando los recursos según sea necesario.
#
# Este tipo de modelado es esencial para la gestión y optimización de procesos industriales, contribuyendo a un funcionamiento más fluido y eficiente de la fábrica de chips. Un claro ejemplo de cómo la programación puede tener un impacto directo en la operación de sistemas complejos.
